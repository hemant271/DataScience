# %%
import pandas as pd
import numpy as np
import spacy
from spacy import displacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
ner_pipeline_labels = nlp.get_pipe("ner").labels
ner_pipeline_labels
# Out:
# ('CARDINAL',
#  'DATE',
#  'EVENT',
#  'FAC',
#  'GPE',
#  'LANGUAGE',
#  'LAW',
#  'LOC',
#  'MONEY',
#  'NORP',
#  'ORDINAL',
#  'ORG',
#  'PERCENT',
#  'PERSON',
#  'PRODUCT',
#  'QUANTITY',
#  'TIME',
#  'WORK_OF_ART')

# %%
spacy.explain('ORG')
# Out:
# 'Companies, agencies, institutions, etc.'

# %%
sample_text = """ The company was founded in December 2002 by Reid Hoffman and the founding team members from PayPal and Socialnet.com (Allen Blue, Eric Ly, Jean-Luc Vaillant, Lee Hower, Konstantin Guericke, Stephen Beitzel, David Eves, Ian McNish, Yan Pujante, Chris Saccheri).In late 2003, Sequoia Capital led the Series A investment in the company.In August 2004, LinkedIn reached 1 million users.In March 2006, LinkedIn achieved its first month of profitability.In April 2007, LinkedIn reached 10 million users.In February 2008, LinkedIn launched a mobile version of the site.

In June 2008, Sequoia Capital, Greylock Partners, and other venture capital firms purchased a 5% stake in the company for $53 million, giving the company a post-money valuation of approximately $1 billion. In November 2009, LinkedIn opened its office in Mumbai and soon thereafter in Sydney, as it started its Asia-Pacific team expansion. In 2010 LinkedIn opened an International Headquarters in Dublin, Ireland,received a $20 million investment from Tiger Global Management LLC at a valuation of approximately $2 billion,announced its first acquisition, Mspoke,and improved its 1% premium subscription ratio. In October of that year, Silicon Valley Insider ranked the company No. 10 on its Top 100 List of most valuable startups. By December, the company was valued at $1.575 billion in private markets. LinkedIn started its India operations in 2009 and a major part of the first year was dedicated to understanding professionals in India and educating members to leverage LinkedIn for career development.

LinkedIn office building at 222 Second Street in San Francisco (opened in March 2016)

LinkedIn office in Toronto inside the Toronto Eaton Centre

LinkedIn filed for an initial public offering in January 2011. The company traded its first shares on May 19, 2011, under the NYSE symbol "LNKD", at $45 per share. Shares of LinkedIn rose as much as 171% on their first day of trade on the New York Stock Exchange and closed at $94.25, more than 109% above IPO price. Shortly after the IPO, the site's underlying infrastructure was revised to allow accelerated revision-release cycles.In 2011 LinkedIn earned $154.6 million in advertising revenue alone, surpassing Twitter, which earned $139.5 million.LinkedIn's fourth-quarter 2011, earnings soared because of the company's increase in success in the social media world.[33] By this point LinkedIn had about 2,100 full-time employees compared to the 500 that it had in 2010.

In April 2014 LinkedIn announced that it had leased 222 Second Street, a 26-story building under construction in San Francisco's SoMa district, to accommodate up to 2,500 of its employees, with the lease covering 10 years.The goal was to join all San Francisco-based staff (1,250 as of January 2016) in one building, bringing sales and marketing employees together with the research and development team.They started to move in in March 2016. In February 2016 following an earnings report, LinkedIn's shares dropped 43.6% within a single day, down to $108.38 per share. LinkedIn lost $10 billion of its market capitalization that day.

In 2016 access to LinkedIn was blocked by Russian authorities for non-compliance with the 2015 national legislation that requires social media networks to store citizens' personal data on servers located in Russia.

In June 2016 Microsoft announced that it would acquire LinkedIn for $196 a share, a total value of $26.2 billion and the second largest acquisition made by Microsoft to date. The acquisition would be an all-cash, debt-financed transaction. Microsoft would allow LinkedIn to "retain its distinct brand, culture and independence", with Weiner to remain as CEO, who would then report to Microsoft CEO Satya Nadella. Analysts believed Microsoft saw the opportunity to integrate LinkedIn with its Office product suite to help better integrate the professional network system with its products. The deal was completed on December 8, 2016.

In late 2016 LinkedIn announced a planned increase of 200 new positions in its Dublin office, which would bring the total employee count to 1,200.Since 2017 94% of B2B marketers use LinkedIn to distribute content.

Soon after LinkedIn's acquisition by Microsoft, LinkedIn's new desktop version was introduced.The new version was meant to make the user experience seamless across mobile and desktop. Some of the changes were made according to the feedback received from the previously launched mobile app. Features that were not heavily used were removed. For example, the contact tagging and filtering features are not supported anymore.

Following the launch of the new user interface (UI), some users, complained about the missing features which were there in the older version, slowness, and bugs in it. The issues were faced by both free and premium users, and with both the desktop version and the mobile version of the site.

In 2019 LinkedIn launched globally the feature Open for Business that enables freelancers to be discovered on the platform.LinkedIn Events was launched in the same year.

In June 2020 Jeff Weiner stepped down as CEO and become executive chairman after 11 years in the role. Ryan Roslansky stepped up as CEO from his previous position as the senior vice president of product.In late July 2020, LinkedIn announced it laid off 960 employees, about 6 percent of total workforce, from the talent acquisition and global sales teams. In an email to all employees, CEO Ryan Roslansky said the cuts were due to effects of the global COVID-19 pandemic.In April 2021 CyberNews claimed that 500 million LinkedIn's accounts have leaked online.However, LinkedIn stated that "We have investigated an alleged set of LinkedIn data that has been posted for sale and have determined that it is actually an aggregation of data from a number of websites and companies".

In June 2021 PrivacySharks claimed that more than 700 million LinkedIn records was on sale on a hacker forum.LinkedIn later stated that this is not a breach, but scraped data which is also a violation of their Terms of Service.

Microsoft ended LinkedIn operations in China in October 2021"""

# %%
len(sample_text.split('.'))
# Out:
# 59

# %%
ner_text = nlp(sample_text)

# %%
for word in ner_text.ents:
    print(word.text,word.label_,word.start_char, word.end_char)
# Out:
# December 2002 DATE 28 41
# Reid Hoffman PERSON 45 57
# PayPal ORG 93 99
# Socialnet.com ORG 104 117
# Allen Blue PERSON 119 129
# Eric Ly PERSON 131 138
# Jean-Luc Vaillant ORG 140 157
# Lee Hower PERSON 159 168
# Konstantin Guericke PERSON 170 189
# Stephen Beitzel PERSON 191 206
# David Eves PERSON 208 218
# Ian McNish PERSON 220 230
# Yan Pujante PERSON 232 243
# Chris PERSON 245 250
# late 2003 DATE 264 273
# Sequoia Capital ORG 275 290
# Series EVENT 299 305
# August 2004 DATE 337 348
# LinkedIn GPE 350 358
# 1 million CARDINAL 367 376
# March 2006 DATE 386 396
# LinkedIn GPE 398 406
# April 2007 DATE 452 462
# LinkedIn GPE 464 472
# 10 million CARDINAL 481 491
# February 2008 DATE 501 514
# LinkedIn GPE 516 524
# June 2008 DATE 568 577
# Sequoia Capital ORG 579 594
# Greylock Partners ORG 596 613
# 5% PERCENT 659 661
# $53 million MONEY 687 698
# approximately $1 billion MONEY 745 769
# November 2009 DATE 774 787
# LinkedIn GPE 789 797
# Mumbai GPE 819 825
# Sydney GPE 849 855
# Asia LOC 875 879
# 2010 DATE 907 911
# LinkedIn GPE 912 920
# Dublin GPE 961 967
# Ireland GPE 969 976
# $20 million MONEY 988 999
# Tiger Global Management ORG 1016 1039
# approximately $2 billion MONEY 1062 1086
# first ORDINAL 1101 1106
# Mspoke ORG 1120 1126
# 1% PERCENT 1144 1146
# October of that year DATE 1178 1198
# Silicon Valley Insider LOC 1200 1222
# 10 CARDINAL 1246 1248
# December DATE 1299 1307
# $1.575 billion MONEY 1335 1349
# LinkedIn GPE 1370 1378
# India GPE 1391 1396
# 2009 DATE 1411 1415
# the first year DATE 1436 1450
# India GPE 1499 1504
# LinkedIn GPE 1539 1547
# LinkedIn GPE 1573 1581
# 222 Second Street MONEY 1601 1618
# San Francisco GPE 1622 1635
# March 2016 DATE 1647 1657
# LinkedIn GPE 1660 1668
# Toronto GPE 1679 1686
# the Toronto Eaton Centre
#
# LinkedIn ORG 1694 1728
# January 2011 DATE 1769 1781
# first ORDINAL 1806 1811
# May 19, 2011 DATE 1822 1834
# NYSE ORG 1846 1850
# 45 MONEY 1870 1872
# LinkedIn GPE 1894 1902
# as much as 171% PERCENT 1908 1923
# their first day DATE 1927 1942
# the New York Stock Exchange ORG 1955 1982
# 94.25 MONEY 1998 2003
# more than 109% PERCENT 2005 2019
# IPO ORG 2026 2029
# IPO ORG 2055 2058
# 2011 DATE 2157 2161
# LinkedIn GPE 2162 2170
# $154.6 million MONEY 2178 2192
# Twitter PRODUCT 2234 2241
# $139.5 million MONEY 2256 2270
# LinkedIn GPE 2271 2279
# fourth-quarter 2011 DATE 2282 2301
# LinkedIn GPE 2409 2417
# about 2,100 CARDINAL 2422 2433
# 500 CARDINAL 2470 2473
# 2010 DATE 2489 2493
# April 2014 DATE 2499 2509
# LinkedIn GPE 2510 2518
# 222 Second Street PRODUCT 2548 2565
# 26 CARDINAL 2569 2571
# San Francisco's GPE 2609 2624
# up to 2,500 CARDINAL 2655 2666
# 10 years DATE 2709 2717
# San Francisco GPE 2743 2756
# 1,250 CARDINAL 2770 2775
# January 2016 DATE 2782 2794
# one CARDINAL 2799 2802
# March 2016 DATE 2927 2937
# February 2016 DATE 2942 2955
# LinkedIn ORG 2986 2994
# 43.6% PERCENT 3012 3017
# a single day DATE 3025 3037
# 108.38 MONEY 3048 3054
# LinkedIn ORG 3066 3074
# $10 billion MONEY 3080 3091
# that day DATE 3121 3129
# 2016 DATE 3135 3139
# LinkedIn GPE 3150 3158
# Russian NORP 3174 3181
# 2015 DATE 3222 3226
# Russia GPE 3339 3345
# June 2016 DATE 3351 3360
# Microsoft ORG 3361 3370
# LinkedIn GPE 3403 3411
# 196 MONEY 3417 3420
# $26.2 billion MONEY 3447 3460
# second ORDINAL 3469 3475
# Microsoft ORG 3504 3513
# Microsoft ORG 3588 3597
# LinkedIn GPE 3610 3618
# Weiner ORG 3682 3688
# Microsoft ORG 3732 3741
# Satya Nadella PERSON 3746 3759
# Microsoft ORG 3779 3788
# LinkedIn GPE 3822 3830
# December 8, 2016 DATE 3963 3979
# 200 CARDINAL 4036 4039
# Dublin GPE 4061 4067
# 2017 DATE 4134 4138
# 94% PERCENT 4139 4142
# LinkedIn GPE 4164 4172
# LinkedIn GPE 4208 4216
# Microsoft ORG 4234 4243
# LinkedIn GPE 4245 4253
# UI ORG 4669 4671
# 2019 DATE 4917 4921
# LinkedIn GPE 4922 4930
# Open for Business WORK_OF_ART 4961 4978
# LinkedIn Events ORG 5037 5052
# the same year DATE 5069 5082
# June 2020 DATE 5088 5097
# Jeff Weiner PERSON 5098 5109
# 11 years DATE 5166 5174
# Ryan Roslansky PERSON 5188 5202
# late July 2020 DATE 5291 5305
# LinkedIn GPE 5307 5315
# 960 CARDINAL 5338 5341
# about 6 percent PERCENT 5353 5368
# Ryan Roslansky PERSON 5475 5489
# April 2021 DATE 5559 5569
# CyberNews ORG 5570 5579
# 500 million CARDINAL 5593 5604
# LinkedIn ORG 5605 5613
# LinkedIn GPE 5653 5661
# LinkedIn GPE 5714 5722
# June 2021 DATE 5867 5876
# PrivacySharks ORG 5877 5890
# more than 700 million CARDINAL 5904 5925
# LinkedIn GPE 5926 5934
# LinkedIn GPE 5973 5981
# their Terms of Service ORG 6068 6090
# Microsoft ORG 6093 6102
# LinkedIn GPE 6109 6117
# China GPE 6132 6137
# October 2021 DATE 6141 6153

# %%
len([ent for ent in ner_text.ents if ent.label_ == 'MONEY'])
# Out:
# 14

# %%
displacy.render(ner_text,style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> The company was founded in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     December 2002
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reid Hoffman
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and the founding team members from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PayPal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Socialnet.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Allen Blue
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Eric Ly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jean-Luc Vaillant
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lee Hower
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Konstantin Guericke
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Stephen Beitzel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     David Eves
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ian McNish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Yan Pujante
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chris
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Saccheri).In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     late 2003
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sequoia Capital
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  led the
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Series
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  A investment in the company.In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     August 2004
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LinkedIn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  reached
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  users.In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March 2006
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LinkedIn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  achieved its first month of profitability.In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 2007
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LinkedIn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  reached
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  users.In
# <mark cla

# %%
# !pip install spacy-annotator
# Out:
# Collecting spacy-annotator
#   Downloading spacy_annotator-2.1.3-py3-none-any.whl (6.0 kB)
# Requirement already satisfied: spacy in d:\anaconda3\lib\site-packages (from spacy-annotator) (3.4.1)
# Requirement already satisfied: ipython in d:\anaconda3\lib\site-packages (from spacy-annotator) (7.22.0)
# Requirement already satisfied: ipywidgets>=7.5.1 in d:\anaconda3\lib\site-packages (from spacy-annotator) (7.6.3)
# Requirement already satisfied: pandas in d:\anaconda3\lib\site-packages (from spacy-annotator) (1.2.4)
# Requirement already satisfied: nbformat>=4.2.0 in d:\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->spacy-annotator) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in d:\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->spacy-annotator) (1.0.0)
# Requirement already satisfied: traitlets>=4.3.1 in d:\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->spacy-annotator) (5.0.5)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in d:\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->spacy-annotator) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in d:\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->spacy-annotator) (5.3.4)
# Requirement already satisfied: jupyter-client in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->spacy-annotator) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->spacy-annotator) (6.1)
# Requirement already satisfied: pygments in d:\anaconda3\lib\site-packages (from ipython->spacy-annotator) (2.8.1)
# Requirement already satisfied: jedi>=0.16 in d:\anaconda3\lib\site-packages (from ipython->spacy-annotator) (0.17.2)
# Requirement already satisfied: backcall in d:\anaconda3\lib\site-packages (from ipython->spacy-annotator) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in d:\anaconda3\lib\site-packages (from ipython->spacy-annotator) (52.0.0.post20210125)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in d:\anaconda3\lib\site-packages (from ipython->spacy-annotator) (3.0.17)
# Requirement already satisfied: colorama in c:\users\hpatidar\appdata\roaming\python\python38\site-packages (from ipython->spacy-annotator) (0.4.3)
# Requirement already satisfied: pickleshare in d:\anaconda3\lib\site-packages (from ipython->spacy-annotator) (0.7.5)
# Requirement already satisfied: decorator in d:\anaconda3\lib\site-packages (from ipython->spacy-annotator) (5.0.6)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in d:\anaconda3\lib\site-packages (from jedi>=0.16->ipython->spacy-annotator) (0.7.0)
# Requirement already satisfied: jupyter-core in d:\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->spacy-annotator) (4.7.1)
# Requirement already satisfied: ipython-genutils in d:\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->spacy-annotator) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in d:\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->spacy-annotator) (3.2.0)
# Requirement already satisfied: six>=1.11.0 in d:\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.1->spacy-annotator) (1.15.0)
# Requirement already satisfied: attrs>=17.4.0 in d:\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.1->spacy-annotator) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in d:\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.1->spacy-annotator) (0.17.3)
# Requirement already satisfied: wcwidth in d:\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->spacy-annotator) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in d:\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->spacy-annotator) (6.3.0)
# Requirement already satisfied: terminado>=0.8.3 in d:\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->spacy-annotator) (0.9.4)
# Requirement already satisfied: nbconvert in d:\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->spacy-annotator) (6.0.7)
# Requirement already satisfied: jinja2 in d:\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->spacy-annotator) (2.11.3)
# Requirement already satisfied: Send2Trash>=1.5.0 in d:\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->spacy-annotator) (1.5.0)
# Requirement already satisfied: prometheus-client in d:\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->spacy-annotator) (0.10.1)
# Requirement already satisfied: pyzmq>=17 in d:\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->spacy-annotator) (20.0.0)
# Requirement already satisfied: argon2-cffi in d:\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->spacy-annotator) (20.1.0)
# Requirement already satisfied: python-dateutil>=2.1 in d:\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.5.1->spacy-annotator) (2.8.1)
# Requirement already satisfied: pywin32>=1.0 in d:\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.5.1->spacy-annotator) (227)
# Requirement already satisfied: pywinpty>=0.5 in d:\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->spacy-annotator) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in d:\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->spacy-annotator) (1.14.5)
# Requirement already satisfied: pycparser in d:\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->spacy-annotator) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->spacy-annotator) (1.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in d:\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->spacy-annotator) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in d:\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->spacy-annotator) (0.3)
# Requirement already satisfied: bleach in d:\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->spacy-annotator) (3.3.0)
# Requirement already satisfied: defusedxml in d:\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->spacy-annotator) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in d:\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->spacy-annotator) (0.5.3)
# Requirement already satisfied: testpath in d:\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->spacy-annotator) (0.4.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->spacy-annotator) (1.4.3)
# Requirement already satisfied: jupyterlab-pygments in d:\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->spacy-annotator) (0.1.2)
# Requirement already satisfied: nest-asyncio in d:\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->spacy-annotator) (1.5.1)
# Requirement already satisfied: async-generator in d:\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->spacy-annotator) (1.10)
# Requirement already satisfied: webencodings in d:\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->spacy-annotator) (0.5.1)
# Requirement already satisfied: packaging in d:\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->spacy-annotator) (20.9)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\anaconda3\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->spacy-annotator) (2.4.7)
# Requirement already satisfied: numpy>=1.16.5 in d:\anaconda3\lib\site-packages (from pandas->spacy-annotator) (1.20.1)
# Requirement already satisfied: pytz>=2017.3 in d:\anaconda3\lib\site-packages (from pandas->spacy-annotator) (2021.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in d:\anaconda3\lib\site-packages (from spacy->spacy-annotator) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in d:\anaconda3\lib\site-packages (from spacy->spacy-annotator) (2.0.7)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in d:\anaconda3\lib\site-packages (from spacy->spacy-annotator) (2.4.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in d:\anaconda3\lib\site-packages (from spacy->spacy-annotator) (2.25.1)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in d:\anaconda3\lib\site-packages (from spacy->spacy-annotator) (0.4.2)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in d:\anaconda3\lib\site-packages (from spacy->spacy-annotator) (8.1.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in d:\anaconda3\lib\site-packages (from spacy->spacy-annotator) (4.59.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in d:\anaconda3\lib\site-packages (from spacy->spacy-annotator) (3.3.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in d:\anaconda3\lib\site-packages (from spacy->spacy-annotator) (1.9.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in d:\anaconda3\lib\site-packages (from spacy->spacy-annotator) (3.0.8)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in d:\anaconda3\lib\site-packages (from spacy->spacy-annotator) (0.10.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in d:\anaconda3\lib\site-packages (from spacy->spacy-annotator) (1.0.4)
# Requirement already satisfied: pathy>=0.3.5 in d:\anaconda3\lib\site-packages (from spacy->spacy-annotator) (0.10.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in d:\anaconda3\lib\site-packages (from spacy->spacy-annotator) (2.0.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in d:\anaconda3\lib\site-packages (from spacy->spacy-annotator) (3.0.11)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in d:\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy->spacy-annotator) (6.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4->spacy->spacy-annotator) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->spacy-annotator) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->spacy-annotator) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in d:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->spacy-annotator) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in d:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->spacy-annotator) (4.0.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in d:\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy->spacy-annotator) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in d:\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy->spacy-annotator) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in d:\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy->spacy-annotator) (7.1.2)
# Installing collected packages: spacy-annotator
# Successfully installed spacy-annotator-2.1.3

# %%
import spacy_annotator as spa
from pprint import pprint

# %%
sample_text_list = sample_text.split('\n')
sample_text_list = [item for item in sample_text_list if item]
print(len(sample_text_list))
print(sample_text_list)
# Out:
# 15
# [' The company was founded in December 2002 by Reid Hoffman and the founding team members from PayPal and Socialnet.com (Allen Blue, Eric Ly, Jean-Luc Vaillant, Lee Hower, Konstantin Guericke, Stephen Beitzel, David Eves, Ian McNish, Yan Pujante, Chris Saccheri).In late 2003, Sequoia Capital led the Series A investment in the company.In August 2004, LinkedIn reached 1 million users.In March 2006, LinkedIn achieved its first month of profitability.In April 2007, LinkedIn reached 10 million users.In February 2008, LinkedIn launched a mobile version of the site.', 'In June 2008, Sequoia Capital, Greylock Partners, and other venture capital firms purchased a 5% stake in the company for $53 million, giving the company a post-money valuation of approximately $1 billion. In November 2009, LinkedIn opened its office in Mumbai and soon thereafter in Sydney, as it started its Asia-Pacific team expansion. In 2010 LinkedIn opened an International Headquarters in Dublin, Ireland,received a $20 million investment from Tiger Global Management LLC at a valuation of approximately $2 billion,announced its first acquisition, Mspoke,and improved its 1% premium subscription ratio. In October of that year, Silicon Valley Insider ranked the company No. 10 on its Top 100 List of most valuable startups. By December, the company was valued at $1.575 billion in private markets. LinkedIn started its India operations in 2009 and a major part of the first year was dedicated to understanding professionals in India and educating members to leverage LinkedIn for career development.', 'LinkedIn office building at 222 Second Street in San Francisco (opened in March 2016)', 'LinkedIn office in Toronto inside the Toronto Eaton Centre', 'LinkedIn filed for an initial public offering in January 2011. The company traded its first shares on May 19, 2011, under the NYSE symbol "LNKD", at $45 per share. Shares of LinkedIn rose as much as 171% on their first day of trade on the New York Stock Exchange and closed at $94.25, more than 109% above IPO price. Shortly after the IPO, the site\'s underlying infrastructure was revised to allow accelerated revision-release cycles.In 2011 LinkedIn earned $154.6 million in advertising revenue alone, surpassing Twitter, which earned $139.5 million.LinkedIn\'s fourth-quarter 2011, earnings soared because of the company\'s increase in success in the social media world.[33] By this point LinkedIn had about 2,100 full-time employees compared to the 500 that it had in 2010.', "In April 2014 LinkedIn announced that it had leased 222 Second Street, a 26-story building under construction in San Francisco's SoMa district, to accommodate up to 2,500 of its employees, with the lease covering 10 years.The goal was to join all San Francisco-based staff (1,250 as of January 2016) in one building, bringing sales and marketing employees together with the research and development team.They started to move in in March 2016. In February 2016 following an earnings report, LinkedIn's shares dropped 43.6% within a single day, down to $108.38 per share. LinkedIn lost $10 billion of its market capitalization that day.", "In 2016 access to LinkedIn was blocked by Russian authorities for non-compliance with the 2015 national legislation that requires social media networks to store citizens' personal data on servers located in Russia.", 'In June 2016 Microsoft announced that it would acquire LinkedIn for $196 a share, a total value of $26.2 billion and the second largest acquisition made by Microsoft to date. The acquisition would be an all-cash, debt-financed transaction. Microsoft would allow LinkedIn to "retain its distinct brand, culture and independence", with Weiner to remain as CEO, who would then report to Microsoft CEO Satya Nadella. Analysts believed Microsoft saw the opportunity to integrate LinkedIn with its Office product suite to help better integrate the professional network system with its products. The deal was completed on December 8, 2016.' ...

# %%
df = pd.DataFrame({'text': sample_text_list})

# %%
df
# Out:
#                                                  text
# 0    The company was founded in December 2002 by R...
# 1   In June 2008, Sequoia Capital, Greylock Partne...
# 2   LinkedIn office building at 222 Second Street ...
# 3   LinkedIn office in Toronto inside the Toronto ...
# 4   LinkedIn filed for an initial public offering ...
# 5   In April 2014 LinkedIn announced that it had l...
# 6   In 2016 access to LinkedIn was blocked by Russ...
# 7   In June 2016 Microsoft announced that it would...
# 8   In late 2016 LinkedIn announced a planned incr...
# 9   Soon after LinkedIn's acquisition by Microsoft...
# 10  Following the launch of the new user interface...
# 11  In 2019 LinkedIn launched globally the feature...
# 12  In June 2020 Jeff Weiner stepped down as CEO a...
# 13  In June 2021 PrivacySharks claimed that more t...
# 14  Microsoft ended LinkedIn operations in China i...

# %%
nlp = spacy.load("en_core_web_sm")

# %%
annotator = spa.Annotator(labels = ['company', 'person', 'money', 'place', 'date'], model = nlp)

# %%
df_labels = annotator.annotate(df = df, col_text = 'text')
# Out:
# HTML(value='-1 examples annotated, 16 examples left')
# Text(value='', description='company', layout=Layout(width='auto'), placeholder='ent one, ent two, ent three')
# Text(value='', description='person', layout=Layout(width='auto'), placeholder='ent one, ent two, ent three')
# Text(value='', description='money', layout=Layout(width='auto'), placeholder='ent one, ent two, ent three')
# Text(value='', description='place', layout=Layout(width='auto'), placeholder='ent one, ent two, ent three')
# Text(value='', description='date', layout=Layout(width='auto'), placeholder='ent one, ent two, ent three')
# HBox(children=(Button(button_style='success', description='submit', style=ButtonStyle()), Button(button_style=…
# Output()
